# %%
import tweepy
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from tweepy.parsers import JSONParser
import json

# %%
access_token = '952716301851652096-Zdn01tpFWXOcTbPuHdye0LkeL4dcyW8'
access_token_secret = 'TDnC2QSAIzJN1uZcwwG3ZFYru5D2KSEg2KoKJz48uIRPV'
consumer_key = 'aLSimwfXagEX2RfBBmRRq9Mxs'
consumer_secret = 'U99xcJ8DkwKtrIm2tzfCmnQJovmbHef7L9BLDmjJTYgkomEwfP'

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,parser = JSONParser())

# %%
visible_public_tweets = api.search(q='$GLD',rpp=5)#,page=5)

json_str =json.dumps(visible_public_tweets)

# %%
test = json.loads(json_str)

# %%
test
# Out:
# {'statuses': [{'created_at': 'Tue Jul 31 16:00:06 +0000 2018',
#    'id': 1024323830922268673,
#    'id_str': '1024323830922268673',
#    'text': 'MoviePass $HMNY Bottom SCALP of the Century $HMNY .46 (-33.43%) $ROKU $GOOGL $DIS $CMCSA $CBS $FOXA $NFLX $AMZN… https://t.co/Ma6f4i5oJY',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'HMNY', 'indices': [10, 15]},
#      {'text': 'HMNY', 'indices': [44, 49]},
#      {'text': 'ROKU', 'indices': [64, 69]},
#      {'text': 'GOOGL', 'indices': [70, 76]},
#      {'text': 'DIS', 'indices': [77, 81]},
#      {'text': 'CMCSA', 'indices': [82, 88]},
#      {'text': 'CBS', 'indices': [89, 93]},
#      {'text': 'FOXA', 'indices': [94, 99]},
#      {'text': 'NFLX', 'indices': [100, 105]},
#      {'text': 'AMZN', 'indices': [106, 111]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Ma6f4i5oJY',
#       'expanded_url': 'https://twitter.com/i/web/status/1024323830922268673',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 35573015,
#     'id_str': '35573015',
#     'name': 'Charts. Technical. Scalp to Long Term. Elliotwave',
#     'screen_name': 'VegasTours',
#     'location': 'Las Vegas, NV',
#     'description': 'All posts are for info only & NOT a recommendation and/or solicitation to buy, sell, hold stocks, bonds, mutual funds.',
#     'url': 'https://t.co/6nabCMz6Rl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6nabCMz6Rl',
#         'expanded_url': 'https://twitter.com/VegasTours',
#         'display_url': 'twitter.com/VegasTours',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12662,
#     'friends_count': 5087,
#     'listed_count': 228,
#     'created_at': 'Sun Apr 26 21:39:05 +0000 2009',
#     'favourites_count': 103,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 17,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '030302',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1024099286496174080/lOPiDtIu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1024099286496174080/lOPiDtIu_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35573015/1532999320',
#     'profile_link_color': '000090',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F7F7F7',
#     'profile_text_color': '070117',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:58:19 +0000 2018',
#    'id': 1024323379665354755,
#    'id_str': '1024323379665354755',
#    'text': 'RT @ViciousTrading: Interesting $btc $gld https://t.co/ju65gkXpv4',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'btc', 'indices': [32, 36]},
#      {'text': 'gld', 'indices': [37, 41]}],
#     'user_mentions': [{'screen_name': 'ViciousTrading',
#       'name': 'Vicious',
#       'id': 898340050483761152,
#       'id_str': '898340050483761152',
#       'indices': [3, 18]}],
#     'urls': [],
#     'media': [{'id': 1023964101406384129,
#       'id_str': '1023964101406384129',
#       'indices': [42, 65],
#       'media_url': 'http://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#       'url': 'https://t.co/ju65gkXpv4',
#       'display_url': 'pic.twitter.com/ju65gkXpv4',
#       'expanded_url': 'https://twitter.com/ViciousTrading/status/1023964108792578048/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 569, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 682, 'h': 571, 'resize': 'fit'},
#        'large': {'w': 682, 'h': 571, 'resize': 'fit'}},
#       'source_status_id': 1023964108792578048,
#       'source_status_id_str': '1023964108792578048',
#       'source_user_id': 898340050483761152,
#       'source_user_id_str': '898340050483761152'}]},
#    'extended_entities': {'media': [{'id': 1023964101406384129,
#       'id_str': '1023964101406384129',
#       'indices': [42, 65],
#       'media_url': 'http://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#       'url': 'https://t.co/ju65gkXpv4',
#       'display_url': 'pic.twitter.com/ju65gkXpv4',
#       'expanded_url': 'https://twitter.com/ViciousTrading/status/1023964108792578048/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 569, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 682, 'h': 571, 'resize': 'fit'},
#        'large': {'w': 682, 'h': 571, 'resize': 'fit'}},
#       'source_status_id': 1023964108792578048,
#       'source_status_id_str': '1023964108792578048',
#       'source_user_id': 898340050483761152,
#       'source_user_id_str': '898340050483761152'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 983782534940057600,
#     'id_str': '983782534940057600',
#     'name': 'Christopher Henry',
#     'screen_name': 'Christ759264',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45,
#     'friends_count': 80,
#     'listed_count': 0,
#     'created_at': 'Tue Apr 10 19:03:28 +0000 2018',
#     'favourites_count': 990,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 614,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Jul 30 16:10:42 +0000 2018',
#     'id': 1023964108792578048,
#     'id_str': '1023964108792578048',
#     'text': 'Interesting $btc $gld https://t.co/ju65gkXpv4',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'btc', 'indices': [12, 16]},
#       {'text': 'gld', 'indices': [17, 21]}],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1023964101406384129,
#        'id_str': '1023964101406384129',
#        'indices': [22, 45],
#        'media_url': 'http://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#        'url': 'https://t.co/ju65gkXpv4',
#        'display_url': 'pic.twitter.com/ju65gkXpv4',
#        'expanded_url': 'https://twitter.com/ViciousTrading/status/1023964108792578048/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 680, 'h': 569, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 682, 'h': 571, 'resize': 'fit'},
#         'large': {'w': 682, 'h': 571, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1023964101406384129,
#        'id_str': '1023964101406384129',
#        'indices': [22, 45],
#        'media_url': 'http://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DjXZ7M8UYAEG5Wf.jpg',
#        'url': 'https://t.co/ju65gkXpv4',
#        'display_url': 'pic.twitter.com/ju65gkXpv4',
#        'expanded_url': 'https://twitter.com/ViciousTrading/status/1023964108792578048/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 680, 'h': 569, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 682, 'h': 571, 'resize': 'fit'},
#         'large': {'w': 682, 'h': 571, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 898340050483761152,
#      'id_str': '898340050483761152',
#      'name': 'Vicious',
#      'screen_name': 'ViciousTrading',
#      'location': 'Québec',
#      'description': 'Slaying the Markets ~ Technical Momentum Trader - Tweets are strictly my opinions only 🇨🇦',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1293,
#      'friends_count': 62,
#      'listed_count': 18,
#      'created_at': 'Fri Aug 18 00:25:33 +0000 2017',
#      'favourites_count': 6207,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4187,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/909890144223756288/3j1MzeXG_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909890144223756288/3j1MzeXG_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 20,
#     'favorite_count': 43,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 20,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:56:33 +0000 2018',
#    'id': 1024322935690076160,
#    'id_str': '1024322935690076160',
#    'text': 'XAUUSD /4H/ Gold long till resistance 1240? https://t.co/Ku0zpa9aAV $XAUUSD $GLD #GC_F $GOLD',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'GC_F', 'indices': [81, 86]}],
#     'symbols': [{'text': 'XAUUSD', 'indices': [68, 75]},
#      {'text': 'GLD', 'indices': [76, 80]},
#      {'text': 'GOLD', 'indices': [87, 92]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Ku0zpa9aAV',
#       'expanded_url': 'http://www.tradingview.com/v/HVO4tJ1E/',
#       'display_url': 'tradingview.com/v/HVO4tJ1E/',
#       'indices': [44, 67]}]},
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 756596389363187712,
#     'id_str': '756596389363187712',
#     'name': 'Gold USDX',
#     'screen_name': 'goldusdx',
#     'location': 'Fort Knox, KY',
#     'description': 'News and technical analysis (via TradingView) on $gold, $gld, $xauusd, and gold miners. https://t.co/9SnySC7HY2, https://t.co/ilWwapg4qr (via @dvolatility)',
#     'url': 'https://t.co/1QVjo7XVsx',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1QVjo7XVsx',
#         'expanded_url': 'https://net.dvolatility.com',
#         'display_url': 'net.dvolatility.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/9SnySC7HY2',
#         'expanded_url': 'https://dvolatility.com',
#         'display_url': 'dvolatility.com',
#         'indices': [88, 111]},
#        {'url': 'https://t.co/ilWwapg4qr',
#         'expanded_url': 'https://pro.dvolatility.com',
#         'display_url': 'pro.dvolatility.com',
#         'indices': [113, 136]}]}},
#     'protected': False,
#     'followers_count': 1247,
#     'friends_count': 17,
#     'listed_count': 30,
#     'created_at': 'Fri Jul 22 21:06:50 +0000 2016',
#     'favourites_count': 27,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 16072,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/769277760824946688/P45emsbs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/769277760824946688/P45emsbs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/756596389363187712/1472244992',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'in'},
#   {'created_at': 'Tue Jul 31 15:56:32 +0000 2018',
#    'id': 1024322932003282944,
#    'id_str': '1024322932003282944',
#    'text': 'RT @TNR_Gold: #TNRGold provides significant exposure to #gold, #copper and #lithium through its holdings in #Alaska (the Shotgun gold porph…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'TNRGold', 'indices': [14, 22]},
#      {'text': 'gold', 'indices': [56, 61]},
#      {'text': 'copper', 'indices': [63, 70]},
#      {'text': 'lithium', 'indices': [75, 83]},
#      {'text': 'Alaska', 'indices': [108, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TNR_Gold',
#       'name': 'TNR Gold Corp.',
#       'id': 462274812,
#       'id_str': '462274812',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.cobaltmining.com" rel="nofollow">cobalter27</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 855146797987053568,
#     'id_str': '855146797987053568',
#     'name': 'Cobalter',
#     'screen_name': 'cobalter27',
#     'location': 'Western USA',
#     'description': '⛏ Your source for the latest information on CRITICAL MINERALS',
#     'url': 'https://t.co/enGmeWszFh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/enGmeWszFh',
#         'expanded_url': 'https://mineralhapps.com',
#         'display_url': 'mineralhapps.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 114,
#     'friends_count': 48,
#     'listed_count': 3,
#     'created_at': 'Thu Apr 20 19:50:59 +0000 2017',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3137,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/991259315540410368/8RBJWpU6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/991259315540410368/8RBJWpU6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/855146797987053568/1529444931',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Jul 31 11:32:56 +0000 2018',
#     'id': 1024256595662962688,
#     'id_str': '1024256595662962688',
#     'text': '#TNRGold provides significant exposure to #gold, #copper and #lithium through its holdings in #Alaska (the Shotgun… https://t.co/PlfU5svXHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'TNRGold', 'indices': [0, 8]},
#       {'text': 'gold', 'indices': [42, 47]},
#       {'text': 'copper', 'indices': [49, 56]},
#       {'text': 'lithium', 'indices': [61, 69]},
#       {'text': 'Alaska', 'indices': [94, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PlfU5svXHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1024256595662962688',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 462274812,
#      'id_str': '462274812',
#      'name': 'TNR Gold Corp.',
#      'screen_name': 'TNR_Gold',
#      'location': 'Vancouver, BC (TSX.V: TNR)',
#      'description': '(TSX-V: TNR) Power of Blue Sky #Discoveries + #Green #Technology. #Green #Energy #Metals #Royalty Company. https://t.co/muuZbYAYi2',
#      'url': 'https://t.co/sc0CTZenqy',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/sc0CTZenqy',
#          'expanded_url': 'http://www.tnrgoldcorp.com/#',
#          'display_url': 'tnrgoldcorp.com/#',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/muuZbYAYi2',
#          'expanded_url': 'http://tnrgoldcorp.com/investors/disclaimer/',
#          'display_url': 'tnrgoldcorp.com/investors/disc…',
#          'indices': [107, 130]}]}},
#      'protected': False,
#      'followers_count': 2186,
#      'friends_count': 2293,
#      'listed_count': 186,
#      'created_at': 'Thu Jan 12 19:33:36 +0000 2012',
#      'favourites_count': 28482,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 36436,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '1568B0',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000540233318/80e8ae4c675ea770cfdcfc4bdee19598_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000540233318/80e8ae4c675ea770cfdcfc4bdee19598_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/462274812/1380758037',
#      'profile_link_color': '0099CC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'F6FFD1',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:55:04 +0000 2018',
#    'id': 1024322563550392320,
#    'id_str': '1024322563550392320',
#    'text': '$GLD Sept 28th 116.00 call 2.04',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GLD', 'indices': [0, 4]}],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 109671883,
#     'id_str': '109671883',
#     'name': 'Konye Bisong',
#     'screen_name': 'Dreamestorical',
#     'location': '',
#     'description': 'Swing Trader/Investor',
#     'url': 'https://t.co/543mdIeeVr',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/543mdIeeVr',
#         'expanded_url': 'https://steemit.com/@dreamestorical',
#         'display_url': 'steemit.com/@dreamestorical',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 334,
#     'friends_count': 181,
#     'listed_count': 16,
#     'created_at': 'Fri Jan 29 21:36:57 +0000 2010',
#     'favourites_count': 4347,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7112,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'EBEBEB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/979772493157289985/PPmd6UP8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/979772493157289985/PPmd6UP8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/109671883/1477840292',
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'DFDFDF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:54:01 +0000 2018',
#    'id': 1024322299422564352,
#    'id_str': '1024322299422564352',
#    'text': '2018-07-30 Short sale volume (not short interest) for $GLD is 75%. https://t.co/GPv1U8xBUZ $DUST 42% $GDXJ 58% $GDX 58% $NUGT 55%',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GLD', 'indices': [54, 58]},
#      {'text': 'DUST', 'indices': [91, 96]},
#      {'text': 'GDXJ', 'indices': [101, 106]},
#      {'text': 'GDX', 'indices': [111, 115]},
#      {'text': 'NUGT', 'indices': [120, 125]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GPv1U8xBUZ',
#       'expanded_url': 'http://shortvolumes.com/?t=GLD',
#       'display_url': 'shortvolumes.com/?t=GLD',
#       'indices': [67, 90]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://shortvolumes.com" rel="nofollow">Short Volumes</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 925001257663811584,
#     'id_str': '925001257663811584',
#     'name': 'shortvolumes',
#     'screen_name': 'shortvolumes',
#     'location': 'New York, USA',
#     'description': 'https://t.co/fwAmxNzbuv is tracking daily short sale volume of stock from some market.',
#     'url': 'https://t.co/fwAmxNzbuv',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/fwAmxNzbuv',
#         'expanded_url': 'http://shortvolumes.com',
#         'display_url': 'shortvolumes.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/fwAmxNzbuv',
#         'expanded_url': 'http://shortvolumes.com',
#         'display_url': 'shortvolumes.com',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 370,
#     'friends_count': 40,
#     'listed_count': 8,
#     'created_at': 'Mon Oct 30 14:07:40 +0000 2017',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 23373,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/926468965198471168/Ydg1FiqU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/926468965198471168/Ydg1FiqU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/925001257663811584/1509722375',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:53:53 +0000 2018',
#    'id': 1024322265712914432,
#    'id_str': '1024322265712914432',
#    'text': 'RT @AdamMancini4: Nice wash lower for $GOLD and recovery as shown by red arrow on my chart 👍Buyers have been stepping in on the dips which…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GOLD', 'indices': [38, 43]}],
#     'user_mentions': [{'screen_name': 'AdamMancini4',
#       'name': 'Adam Mancini',
#       'id': 729435789411618817,
#       'id_str': '729435789411618817',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1635658110,
#     'id_str': '1635658110',
#     'name': 'GP Philosopher',
#     'screen_name': 'GPPhilosopher',
#     'location': '',
#     'description': 'Geo Political Philosopher - Reality, Existence, Knowledge, Values, Reason, Mind and Language -',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 121,
#     'friends_count': 176,
#     'listed_count': 11,
#     'created_at': 'Wed Jul 31 15:02:36 +0000 2013',
#     'favourites_count': 45,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9607,
#     'lang': 'nl',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/630338737361174528/1WqtUaRX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/630338737361174528/1WqtUaRX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1635658110/1439119480',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Jul 31 13:44:28 +0000 2018',
#     'id': 1024289697252761602,
#     'id_str': '1024289697252761602',
#     'text': 'Nice wash lower for $GOLD and recovery as shown by red arrow on my chart 👍Buyers have been stepping in on the dips… https://t.co/MDQIITH4Ia',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'GOLD', 'indices': [20, 25]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MDQIITH4Ia',
#        'expanded_url': 'https://twitter.com/i/web/status/1024289697252761602',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 729435789411618817,
#      'id_str': '729435789411618817',
#      'name': 'Adam Mancini',
#      'screen_name': 'AdamMancini4',
#      'location': 'Canada',
#      'description': 'Full-Time Trader (commodities/indices). No-bias, fully transparent approach, trading the same setups every day. Writer. All posts are for my use/notes only!',
#      'url': 'https://t.co/sGzRkCIZV3',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/sGzRkCIZV3',
#          'expanded_url': 'http://seekingalpha.com/author/adam-mancini/articles#regular_articles',
#          'display_url': 'seekingalpha.com/author/adam-ma…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9844,
#      'friends_count': 73,
#      'listed_count': 329,
#      'created_at': 'Sun May 08 22:20:19 +0000 2016',
#      'favourites_count': 7414,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4299,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729435789411618817/1474693753',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1023622194784595970,
#     'quoted_status_id_str': '1023622194784595970',
#     'quoted_status': {'created_at': 'Sun Jul 29 17:32:03 +0000 2018',
#      'id': 1023622194784595970,
#      'id_str': '1023622194784595970',
#      'text': '$GOLD has the ingredients it needs technically for a bounce but its now make or break time: 1) It has finally set a… https://t.co/RqoOUF38yD',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [{'text': 'GOLD', 'indices': [0, 5]}],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/RqoOUF38yD',
#         'expanded_url': 'https://twitter.com/i/web/status/1023622194784595970',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 729435789411618817,
#       'id_str': '729435789411618817',
#       'name': 'Adam Mancini',
#       'screen_name': 'AdamMancini4',
#       'location': 'Canada',
#       'description': 'Full-Time Trader (commodities/indices). No-bias, fully transparent approach, trading the same setups every day. Writer. All posts are for my use/notes only!',
#       'url': 'https://t.co/sGzRkCIZV3',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/sGzRkCIZV3',
#           'expanded_url': 'http://seekingalpha.com/author/adam-mancini/articles#regular_articles',
#           'display_url': 'seekingalpha.com/author/adam-ma…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 9844,
#       'friends_count': 73,
#       'listed_count': 329,
#       'created_at': 'Sun May 08 22:20:19 +0000 2016',
#       'favourites_count': 7414,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 4299,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729435789411618817/1474693753',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 34,
#      'favorite_count': 131,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 11,
#     'favorite_count': 55,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1023622194784595970,
#    'quoted_status_id_str': '1023622194784595970',
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:51:53 +0000 2018',
#    'id': 1024321760089530368,
#    'id_str': '1024321760089530368',
#    'text': '$GLD Short has reached a plateau.... It had a tremendous move from 6/14 to date. Im not waiting around on this one.… https://t.co/KPlDq6C7zA',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GLD', 'indices': [0, 4]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/KPlDq6C7zA',
#       'expanded_url': 'https://twitter.com/i/web/status/1024321760089530368',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 29054610,
#     'id_str': '29054610',
#     'name': 'MrBee',
#     'screen_name': 'MrBee_Trader',
#     'location': 'Palm Beach County Florida',
#     'description': 'Aspiring full time trader.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 183,
#     'friends_count': 70,
#     'listed_count': 2,
#     'created_at': 'Sun Apr 05 20:17:12 +0000 2009',
#     'favourites_count': 1047,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1179,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/948718218323136513/fttD32Ke_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948718218323136513/fttD32Ke_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29054610/1485888080',
#     'profile_link_color': '4338DE',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:49:23 +0000 2018',
#    'id': 1024321132726505475,
#    'id_str': '1024321132726505475',
#    'text': '$PAC.V $PACXF https://t.co/f9k15pPF5x #Stocks #OTC #OTCstocks $GLD $ABX $RGLD',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Stocks', 'indices': [38, 45]},
#      {'text': 'OTC', 'indices': [46, 50]},
#      {'text': 'OTCstocks', 'indices': [51, 61]}],
#     'symbols': [{'text': 'PAC.V', 'indices': [0, 6]},
#      {'text': 'PACXF', 'indices': [7, 13]},
#      {'text': 'GLD', 'indices': [62, 66]},
#      {'text': 'ABX', 'indices': [67, 71]},
#      {'text': 'RGLD', 'indices': [72, 77]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/f9k15pPF5x',
#       'expanded_url': 'http://ow.ly/RMPN30lcyIv',
#       'display_url': 'ow.ly/RMPN30lcyIv',
#       'indices': [14, 37]}]},
#    'metadata': {'iso_language_code': 'fi', 'result_type': 'recent'},
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 569412752,
#     'id_str': '569412752',
#     'name': 'Parker Winter',
#     'screen_name': 'WallSt_Broker',
#     'location': 'New York City',
#     'description': 'Member of the NYSE 20+ years, Providing Investment advice, Forex, Exchange Rate, Pips, Stocks, Stock Market, Finance, Money, Gold, Hedge Funds and Futures.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 661,
#     'friends_count': 667,
#     'listed_count': 31,
#     'created_at': 'Wed May 02 20:48:51 +0000 2012',
#     'favourites_count': 3373,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1366,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/428725202508193793/mADO4CpO_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/428725202508193793/mADO4CpO_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/569412752/1475118983',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fi'},
#   {'created_at': 'Tue Jul 31 15:47:53 +0000 2018',
#    'id': 1024320753309765633,
#    'id_str': '1024320753309765633',
#    'text': '#Gold is at its daily cycle (DC) downtrend line again on the hourly. Bulls need to get through here and back above… https://t.co/6yXucB1Brs',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Gold', 'indices': [0, 5]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/6yXucB1Brs',
#       'expanded_url': 'https://twitter.com/i/web/status/1024320753309765633',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 587925910,
#     'id_str': '587925910',
#     'name': 'Reid',
#     'screen_name': 'reidtrader',
#     'location': '',
#     'description': 'Trader. Setups based on cycles and moving averages.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 322,
#     'friends_count': 104,
#     'listed_count': 5,
#     'created_at': 'Wed May 23 02:01:25 +0000 2012',
#     'favourites_count': 302,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 242,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/814516210679222272/uCzYu9tZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/814516210679222272/uCzYu9tZ_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:47:31 +0000 2018',
#    'id': 1024320662813454337,
#    'id_str': '1024320662813454337',
#    'text': 'Bitmex offers leveraged trading products on digital currencies 😊  \n\nRegister for BONUS ➡️ https://t.co/NdQ0oeVQv4… https://t.co/fRJsIO0KhG',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/NdQ0oeVQv4',
#       'expanded_url': 'http://bitmex.com/register/6vXB0G',
#       'display_url': 'bitmex.com/register/6vXB0G',
#       'indices': [90, 113]},
#      {'url': 'https://t.co/fRJsIO0KhG',
#       'expanded_url': 'https://twitter.com/i/web/status/1024320662813454337',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
# ...
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/756923184746733568/FhIl1Z8N_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/756923184746733568/FhIl1Z8N_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1230912338/1362335703',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:35:28 +0000 2018',
#    'id': 1024317628179988480,
#    'id_str': '1024317628179988480',
#    'text': '" Trump takes up Giuliani\'s line of attack: " Collusion is not a crime " $GLD $SLV https://t.co/gZBRXiFejE',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GLD', 'indices': [73, 77]},
#      {'text': 'SLV', 'indices': [78, 82]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1024317625885765632,
#       'id_str': '1024317625885765632',
#       'indices': [83, 106],
#       'media_url': 'http://pbs.twimg.com/media/DjcbdCQXsAAGsVq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DjcbdCQXsAAGsVq.jpg',
#       'url': 'https://t.co/gZBRXiFejE',
#       'display_url': 'pic.twitter.com/gZBRXiFejE',
#       'expanded_url': 'https://twitter.com/panamaorange/status/1024317628179988480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 432, 'h': 259, 'resize': 'fit'},
#        'large': {'w': 432, 'h': 259, 'resize': 'fit'},
#        'medium': {'w': 432, 'h': 259, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1024317625885765632,
#       'id_str': '1024317625885765632',
#       'indices': [83, 106],
#       'media_url': 'http://pbs.twimg.com/media/DjcbdCQXsAAGsVq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DjcbdCQXsAAGsVq.jpg',
#       'url': 'https://t.co/gZBRXiFejE',
#       'display_url': 'pic.twitter.com/gZBRXiFejE',
#       'expanded_url': 'https://twitter.com/panamaorange/status/1024317628179988480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 432, 'h': 259, 'resize': 'fit'},
#        'large': {'w': 432, 'h': 259, 'resize': 'fit'},
#        'medium': {'w': 432, 'h': 259, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://stocktwits.com" rel="nofollow">StockTwits Web</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 65208304,
#     'id_str': '65208304',
#     'name': 'panamaorange',
#     'screen_name': 'panamaorange',
#     'location': 'straight outta innsmouth ',
#     'description': "' ' I made all my generals out of mud ' '\n\n\n\n-  Napoleon",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1785,
#     'friends_count': 315,
#     'listed_count': 114,
#     'created_at': 'Thu Aug 13 00:01:10 +0000 2009',
#     'favourites_count': 4504,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 47929,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/855600445758337025/eVpAwdz8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/855600445758337025/eVpAwdz8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/65208304/1380909320',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Jul 31 15:35:20 +0000 2018',
#    'id': 1024317595560955904,
#    'id_str': '1024317595560955904',
#    'text': 'RT @AdamMancini4: Nice wash lower for $GOLD and recovery as shown by red arrow on my chart 👍Buyers have been stepping in on the dips which…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'GOLD', 'indices': [38, 43]}],
#     'user_mentions': [{'screen_name': 'AdamMancini4',
#       'name': 'Adam Mancini',
#       'id': 729435789411618817,
#       'id_str': '729435789411618817',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1856959248,
#     'id_str': '1856959248',
#     'name': 'ValueTheMarkets',
#     'screen_name': 'ValueTheMarkets',
#     'location': 'UK',
#     'description': 'We are a news website only & do not offer investment advice. We are not regulated by the FCA. More info: https://t.co/U1TkNEZJhk',
#     'url': 'http://t.co/EKD3pdPmLv',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/EKD3pdPmLv',
#         'expanded_url': 'http://www.valuethemarkets.com',
#         'display_url': 'valuethemarkets.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/U1TkNEZJhk',
#         'expanded_url': 'http://www.valuethemarkets.com/index.php/disclaimer',
#         'display_url': 'valuethemarkets.com/index.php/disc…',
#         'indices': [105, 128]}]}},
#     'protected': False,
#     'followers_count': 2025,
#     'friends_count': 581,
#     'listed_count': 19,
#     'created_at': 'Thu Sep 12 10:33:06 +0000 2013',
#     'favourites_count': 1992,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4799,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000514978147/9f0b47d0ee298eb719b849abb3054f9e_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000514978147/9f0b47d0ee298eb719b849abb3054f9e_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1856959248/1397060861',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Jul 31 13:44:28 +0000 2018',
#     'id': 1024289697252761602,
#     'id_str': '1024289697252761602',
#     'text': 'Nice wash lower for $GOLD and recovery as shown by red arrow on my chart 👍Buyers have been stepping in on the dips… https://t.co/MDQIITH4Ia',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'GOLD', 'indices': [20, 25]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MDQIITH4Ia',
#        'expanded_url': 'https://twitter.com/i/web/status/1024289697252761602',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 729435789411618817,
#      'id_str': '729435789411618817',
#      'name': 'Adam Mancini',
#      'screen_name': 'AdamMancini4',
#      'location': 'Canada',
#      'description': 'Full-Time Trader (commodities/indices). No-bias, fully transparent approach, trading the same setups every day. Writer. All posts are for my use/notes only!',
#      'url': 'https://t.co/sGzRkCIZV3',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/sGzRkCIZV3',
#          'expanded_url': 'http://seekingalpha.com/author/adam-mancini/articles#regular_articles',
#          'display_url': 'seekingalpha.com/author/adam-ma…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9844,
#      'friends_count': 73,
#      'listed_count': 329,
#      'created_at': 'Sun May 08 22:20:19 +0000 2016',
#      'favourites_count': 7414,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4299,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729435789411618817/1474693753',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1023622194784595970,
#     'quoted_status_id_str': '1023622194784595970',
#     'quoted_status': {'created_at': 'Sun Jul 29 17:32:03 +0000 2018',
#      'id': 1023622194784595970,
#      'id_str': '1023622194784595970',
#      'text': '$GOLD has the ingredients it needs technically for a bounce but its now make or break time: 1) It has finally set a… https://t.co/RqoOUF38yD',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [{'text': 'GOLD', 'indices': [0, 5]}],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/RqoOUF38yD',
#         'expanded_url': 'https://twitter.com/i/web/status/1023622194784595970',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 729435789411618817,
#       'id_str': '729435789411618817',
#       'name': 'Adam Mancini',
#       'screen_name': 'AdamMancini4',
#       'location': 'Canada',
#       'description': 'Full-Time Trader (commodities/indices). No-bias, fully transparent approach, trading the same setups every day. Writer. All posts are for my use/notes only!',
#       'url': 'https://t.co/sGzRkCIZV3',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/sGzRkCIZV3',
#           'expanded_url': 'http://seekingalpha.com/author/adam-mancini/articles#regular_articles',
#           'display_url': 'seekingalpha.com/author/adam-ma…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 9844,
#       'friends_count': 73,
#       'listed_count': 329,
#       'created_at': 'Sun May 08 22:20:19 +0000 2016',
#       'favourites_count': 7414,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 4299,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899127121670541312/ZVBuToeP_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729435789411618817/1474693753',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 34,
#      'favorite_count': 131,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 11,
#     'favorite_count': 55,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1023622194784595970,
#    'quoted_status_id_str': '1023622194784595970',
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.073,
#   'max_id': 1024323830922268673,
#   'max_id_str': '1024323830922268673',
#   'next_results': '?max_id=1024317595560955903&q=%24GLD&include_entities=1',
#   'query': '%24GLD',
#   'refresh_url': '?since_id=1024323830922268673&q=%24GLD&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
type(resultados)
# Out:
# list

# %%
visible_public_tweets = api.search('$GLD')
analyzer = SentimentIntensityAnalyzer()


for tweet in visible_public_tweets:
    print(tweet.text)
    print(82 * '-')
    sentimentAnalyzer = TextBlob(tweet.text)
    print(sentimentAnalyzer.sentiment)
    print(82 * '*')
    sent = analyzer.polarity_scores(tweet.text)
    print('{} {}'.format(tweet.text, sent))
    print(82 * '^')
# Out:
# Bitcoin $BTC price is: $6649.90
#
# Move your trading to the #1 crypto exchange today ! Sign up 🙌 💎
#
# ➡️… https://t.co/ulT0XHOwkj
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# Bitcoin $BTC price is: $6649.90
#
# Move your trading to the #1 crypto exchange today ! Sign up 🙌 💎
#
# ➡️… https://t.co/ulT0XHOwkj {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# $NUGT $JNUG $GDX $GDXJ $GLD $UGLD $SLV $USLV im think all the actions gonna be overnight where the trouble sits others parts of the world...
# ----------------------------------------------------------------------------------
# Sentiment(polarity=-0.2, subjectivity=0.2)
# **********************************************************************************
# $NUGT $JNUG $GDX $GDXJ $GLD $UGLD $SLV $USLV im think all the actions gonna be overnight where the trouble sits others parts of the world... {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'compound': -0.4019}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# #mining $GLD #energy #economy $ES $OIL We are outside raising money for MiningMattersCA through its annual Diamond… https://t.co/TBGiGk1Oz5
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.05)
# **********************************************************************************
# #mining $GLD #energy #economy $ES $OIL We are outside raising money for MiningMattersCA through its annual Diamond… https://t.co/TBGiGk1Oz5 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Current price levels for $PAC.V $PACXF place the shares above the rising trendline
#
# https://t.co/3ooG1nZBAB… https://t.co/Jzs7ouUnQi
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.25)
# **********************************************************************************
# Current price levels for $PAC.V $PACXF place the shares above the rising trendline
#
# https://t.co/3ooG1nZBAB… https://t.co/Jzs7ouUnQi {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.296}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# #mining $GLD #energy #economy $ES $OIL At its phosphate mine in North Carolina, USA, PotashCorp is leveraging techn… https://t.co/bMzEEpAJGn
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# #mining $GLD #energy #economy $ES $OIL At its phosphate mine in North Carolina, USA, PotashCorp is leveraging techn… https://t.co/bMzEEpAJGn {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Gold and silver prices are moderately higher in early U.S. trading Thursday, despite a solid rebound in the U.S. do… https://t.co/jcR1e1rL1v
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.11666666666666665, subjectivity=0.3)
# **********************************************************************************
# Gold and silver prices are moderately higher in early U.S. trading Thursday, despite a solid rebound in the U.S. do… https://t.co/jcR1e1rL1v {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.1139}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Tomorrow Events 15.6.2018
#
# $VIT $LUX $CVC $DCR $PYLNT $MTC $LBTC $AION $STQ $WPR $ZCN $GLD $VIU $OCN $DMB $STARS… https://t.co/XLXtaxzM4S
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# Tomorrow Events 15.6.2018
#
# $VIT $LUX $CVC $DCR $PYLNT $MTC $LBTC $AION $STQ $WPR $ZCN $GLD $VIU $OCN $DMB $STARS… https://t.co/XLXtaxzM4S {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# $PAC.V $PACXF  after being in green for most of the day is now marginally down
#
# https://t.co/ZFF50pXOJj… https://t.co/9OkkBXsEO4
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.048148148148148134, subjectivity=0.362962962962963)
# **********************************************************************************
# $PAC.V $PACXF  after being in green for most of the day is now marginally down
#
# https://t.co/ZFF50pXOJj… https://t.co/9OkkBXsEO4 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How long does #emergingmarkets weakness stay contained? $usd rallying is gotta hurt especially with #fed pulling th… https://t.co/ZXtatyqD50
# ----------------------------------------------------------------------------------
# Sentiment(polarity=-0.025, subjectivity=0.7)
# **********************************************************************************
# How long does #emergingmarkets weakness stay contained? $usd rallying is gotta hurt especially with #fed pulling th… https://t.co/ZXtatyqD50 {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.7351}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Get access to 15+ premium paid groups for a fraction of the price! 💎
#
# Join Us: ➡️ https://t.co/9V3WyLKyNu
#
# $NXC… https://t.co/mTG4USES3W
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# Get access to 15+ premium paid groups for a fraction of the price! 💎
#
# Join Us: ➡️ https://t.co/9V3WyLKyNu
#
# $NXC… https://t.co/mTG4USES3W {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3595}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Value of $EOS is: $11.28
#
# Trade crypto on Binance and get 50% discount on trading fees 🤔 💎
#
# ➡️… https://t.co/fjfS2YNcFk
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# Value of $EOS is: $11.28
#
# Trade crypto on Binance and get 50% discount on trading fees 🤔 💎
#
# ➡️… https://t.co/fjfS2YNcFk {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.34}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 50% discount on all trades, sign up today &amp; enjoy discounts 💎
#
# Register for BONUS ➡️ https://t.co/WbsCd1Jgim… https://t.co/xJ8DVVwFtb
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.4, subjectivity=0.5)
# **********************************************************************************
# 50% discount on all trades, sign up today &amp; enjoy discounts 💎
#
# Register for BONUS ➡️ https://t.co/WbsCd1Jgim… https://t.co/xJ8DVVwFtb {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.8143}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RT @RediminMagazine: #mining $GLD #energy #economy $ES $OIL There is nothing more important on a mine site than keeping people safe. Here a…
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.4666666666666666, subjectivity=0.6666666666666666)
# **********************************************************************************
# RT @RediminMagazine: #mining $GLD #energy #economy $ES $OIL There is nothing more important on a mine site than keeping people safe. Here a… {'neg': 0.073, 'neu': 0.809, 'pos': 0.117, 'compound': 0.2712}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RT @OfficialHemp: 165 Million shares traded @ $HEMP Hemp, Inc. Signs Contract to Plant 25 Acres of #Hemp $GLD $PALL $SLV $NUGT $DUST $GDX $…
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.0, subjectivity=0.0)
# **********************************************************************************
# RT @OfficialHemp: 165 Million shares traded @ $HEMP Hemp, Inc. Signs Contract to Plant 25 Acres of #Hemp $GLD $PALL $SLV $NUGT $DUST $GDX $… {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.296}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# #mining $GLD #energy #economy $ES $OIL There is nothing more important on a mine site than keeping people safe. Her… https://t.co/Z2WLVequIR
# ----------------------------------------------------------------------------------
# Sentiment(polarity=0.4666666666666666, subjectivity=0.6666666666666666)
# **********************************************************************************
# #mining $GLD #energy #economy $ES $OIL There is nothing more important on a mine site than keeping people safe. Her… https://t.co/Z2WLVequIR {'neg': 0.08, 'neu': 0.793, 'pos': 0.128, 'compound': 0.2712}
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
# In Tweepy, an instance of tweepy.Stream establishes a streaming session and
# routes messages to StreamListener instance.
# So first, we need to import the  equisite classes

from tweepy import Stream
from tweepy.streaming import StreamListener
import json

# get the tweets on a specific topic and write the polarity to file
class Listener(StreamListener):
    def on_data(self, data):
        all_data = json.loads(data)
        tweet = all_data["text"]
        sentimentAnalyzer = TextBlob(tweet)
        print(sentimentAnalyzer.sentiment)
        polarity = sentimentAnalyzer.sentiment.polarity
        #subjectivity = sentimentAnalyzer.sentiment.subjectivity
        output = open("/tmp/twitter-out.txt","a")
        output.write(str(polarity))
        output.write('\n')
        output.close()

        return True

    def on_error(self, status):
        print(status)

# Authenticate with Twitter
authen = tweepy.OAuthHandler(consumer_key, consumer_secret)
authen.set_access_token(access_token, access_token_secret)

# Establish a streaming section and route messages to the StreamListener
listener = Listener()
twitterStream = Stream(authen, listener)

# Track tweets related to Musk
twitterStream.filter(track=["Musk"])

# %% [markdown]
# ### AGREGAR MONGO CONNECT FUNCTION

# %%
from tweepy.streaming import StreamListener
import json

class MyStreamListener(StreamListener):
    """
    Streams tweets and saves to a mongoDB database
    """
    
    def __init__(self,api,**kw):
        self.api = api
        super(tweepy.StreamListener,self).__init__()
        self.col = get_mongo_database('tweets',**kw)['tweets']
        
    def on_data(self,tweet):
        self.col.insert(json.loads(tweet))
    
    def on_error(self,status):
        return True # keep stream open

# %%
###########Generate the animated plot#############
#Import the respective classes
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import time

#Apply the "ggplot" style sheet
#More details: https://matplotlib.org/gallery/style_sheets/ggplot.html
style.use("ggplot")

figure = plt.figure()
#To the figure, add a 1 row X 1 column subspot
#More details on subplot: https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot
plotHandle = figure.add_subplot(1,1,1)

def animate(i):
    fetchlData = open("/tmp/twitter-out.txt","r").read()
    dataArray = fetchlData.split('\n')
    xarray = []
    yarray = []

    xcord = 0
    ycord = 0

    for l in range(len(dataArray)):
        xcord += 1
        polarity = dataArray[l]
        #print(float(polarity))
        if len(dataArray[l])>1:
            if float(polarity)>0.0:
                ycord += 1
                #print(y)
            elif float(polarity)<0.0:
                #print(y)
                ycord -= 1

        xarray.append(xcord)
        yarray.append(ycord)
        #print(l)

    plotHandle.clear()
    plotHandle.plot(xarray,yarray)


ani = animation.FuncAnimation(figure, animate, frames=200, interval=20)
plt.show()
