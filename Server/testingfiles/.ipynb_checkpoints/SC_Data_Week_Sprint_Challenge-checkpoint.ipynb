# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Preparation Sprint Challenge
#
# Data preparation can be an arduous process with many steps. These following challenges were all gone over in class.
#
# There are six objectives in Data Preparation:
#
# * select
# * filter
# * treat
# * de-duplicate
# * concatenate
# * transform
#
# There are three objectives in Data Visualization
#
# * Draw an oblique topology
# * Pairplot to find clusters
# * Plot clusters together
#
# Share with mlsubmissions@lambdaschool.com when finished.

# %% [markdown]
# # Select
#
# Load `https://www.dropbox.com/s/xcqdya9svj04kwc/example4.csv?raw=1` and remove any rows that are not data samples.
#
# Print your result and its dimensions.

# %%
df = pd.read_csv('dataset4.csv', skiprows=[0, 2, 3,4])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
print('The dataframe has: {} rows\n                   {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# The dataframe has: 3 rows
#                    5 columns

# %% [markdown]
# # Filter
#
# Only access the rows or columns of a pandas `DataFrame` that you want.
#
# Load `https://www.dropbox.com/s/xcqdya9svj04kwc/example5.csv?raw=1` for these examples.

# %%
df1 = pd.read_csv('dataset5.csv')
df1
# Out:
#   somestuff  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df1['b']
# Out:
# 0     2
# 1     6
# 2    10
# Name: b, dtype: int64

# %%
df1[df1.columns[2]]
# Out:
# 0     2
# 1     6
# 2    10
# Name: b, dtype: int64

# %%
df1.loc[:,['a','message']]
# Out:
#    a message
# 0  1     NaN
# 1  5   world
# 2  9     foo

# %%
df1[['a','message']]
# Out:
#    a message
# 0  1     NaN
# 1  5   world
# 2  9     foo

# %%
df1.loc[0]
# Out:
# somestuff    one
# a              1
# b              2
# c              3
# d              4
# message      NaN
# Name: 0, dtype: object

# %%
df1.loc[[0,2],:]
# Out:
#   somestuff  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 2     three  9  10  11.0  12     foo

# %%
# Print only the third column

# Print columns 'a' and 'message'

# Print the first row

# Print the first and third rows

# %% [markdown]
# # Treat
#
# Load `https://www.dropbox.com/s/9cljswede6r25ho/example5.csv?raw=1` for these examples

# %%
df1
# Out:
#   somestuff  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df1.isnull().sum()
# Out:
# somestuff    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
df11 = df1.copy()
df11.dropna(inplace=True)
df11
# Out:
#   somestuff  a   b     c   d message
# 2     three  9  10  11.0  12     foo

# %%
df1
# Out:
#   somestuff  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# Keep in mind that ffill won't work with message since there is no previous value

df1.fillna(method='ffill',inplace = True)
df1.loc[0,'message'] = 'no value to copy'
df1
# Out:
#   somestuff  a   b     c   d           message
# 0       one  1   2   3.0   4  no value to copy
# 1       two  5   6   3.0   8             world
# 2     three  9  10  11.0  12               foo

# %%
# Print the sum of NaN values in each column

# Drop all ROWS that contain NaN and print the result

# Replace all cells containing NaN using ffill

# %% [markdown]
# # De-Duplicate
#
# Load `https://www.dropbox.com/s/5m89vi5qgu4g2cd/duped.csv?raw=1` for the following

# %%
df2 = pd.read_csv('duped.csv')
df2
# Out:
#    a   b   c
# 0  1   2   3
# 1  1   1   1
# 2  1   2   3
# 3  1   0   3
# 4  3   3   3
# 5  3   3   3
# 6  3   3   1

# %%
df2.drop_duplicates(inplace = True)
df2
# Out:
#    a   b   c
# 0  1   2   3
# 1  1   1   1
# 3  1   0   3
# 4  3   3   3
# 6  3   3   1

# %%
# Print the contents of the dataframe after having dropped all duplicate rows

# %% [markdown]
# # Concatenate
#
# Merge the Titanic and OKC datasets by `age` using `pd.merge` and the `on` argument.

# %%
Titanic = pd.DataFrame({
    'age': [29, 24, 23, 38, 48, 44],
    'name': ['alpha', 'nu', 'gamma', 'psi', 'theta', 'rho']
})
OKC = pd.DataFrame({
    'age': [48, 44, 38, 29, 24, 23],
    'alive': [False, True, False, True, False, True]
})

# Merge and print the result

# %%
pd.merge(Titanic,OKC, on = 'age')
# Out:
#    age   name  alive
# 0   29  alpha   True
# 1   24     nu  False
# 2   23  gamma   True
# 3   38    psi  False
# 4   48  theta  False
# 5   44    rho   True

# %% [markdown]
# # Transform
#
# Use `groupby` to separate the following dataframe by `speed`.

# %%
Rockets = pd.DataFrame({
   'speed': ['fast', 'fast', 'fast', 'slow', 'slow'],
   'engine': ['XX9', '24-Bravo', 'Lambda Nu', 'X1', 'XX8'],
   'name': ['Musky', 'NASO', 'COSMO', 'Zucc', 'Dragon egg']
})

# `groupby` and store the result.

# Iterate over each result and print it on its own line/s

# %%
Rockets
# Out:
#       engine        name speed
# 0        XX9       Musky  fast
# 1   24-Bravo        NASO  fast
# 2  Lambda Nu       COSMO  fast
# 3         X1        Zucc  slow
# 4        XX8  Dragon egg  slow

# %%
grouped = Rockets.groupby(['speed','engine']).count().reset_index()
grouped
# Out:
#   speed     engine  name
# 0  fast   24-Bravo     1
# 1  fast  Lambda Nu     1
# 2  fast        XX9     1
# 3  slow         X1     1
# 4  slow        XX8     1

# %% [markdown]
# ### Notes to the reader:
#
# I used 2 categories to group to give more meaning to the table.
#
# I did not fully understand what you mean by **"Iterate over each result and print it on its own line/s"**, hence I did not do it.

# %% [markdown]
# # Draw an oblique topology
#
# The Mexican Hat Filter or Laplacian of Gaussian is used for cleaning up noisy 2d data, such as in images. It makes a pretty cool 3d graph.
#
# Plot the filter that is returned by the defined function. The range of the function as defined should be interesting from approximately -1 to 1

# %%
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)

X,Y = np.meshgrid(x,y)

def laplacian_of_gaussian(x,y):
    sigma = 0.3
    return 1/np.pi*sigma * (1-0.5*((x**2 + y**2)/sigma**2)) * np.exp(-((x**2+y**2)/(2*sigma**2)))

Z = laplacian_of_gaussian(X,Y)

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig = plt.figure(figsize=(16, 12))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(X,Y,Z, rstride=2, cstride=2,
                       cmap=plt.cm.coolwarm, linewidth=0.5,
                       antialiased=True)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# # Pairplot to find clusters
#
# Clusters have a normal shape along each axis. Pairplot the following data and manually print which axes are normal.
#
# Read your data from `https://www.dropbox.com/s/ziqwkm163ih96v0/sprint_challenge_data.csv?raw=1`

# %%
df4 = pd.read_csv('sprint_challenge_data.csv',index_col=0)
df4.head()
# Out:
#          na        nb    lx         ly         r        ny        nx
# 0 -3.518547  2.415363  23.0  23.444392  0.483178 -2.686564  3.796670
# 1 -2.269976  2.162808  37.0  37.836192  0.230229 -1.731095  2.113713
# 2 -2.602120  2.182037   9.0   9.667870  0.585964 -4.323667  1.897872
# 3 -2.456000  2.583895  28.0  29.091804  0.611946 -1.100922  1.974076
# 4 -3.765145  1.751981  46.0  46.196449  0.278789 -2.275263  2.868828

# %%
import seaborn as sns;sns.set()

sns.pairplot(df4);

# %% [markdown]
# # Plot clusters together
#
# You found the clusters. Draw them on the same graph.

# %% [markdown]
# ### It seems that you have the following nice clusters:
#
#     1. nx - nb
#     2. nx - na
#     3. nb - na

# %%
df4[['nx','nb','na']].describe()
# Out:
#               nx         nb         na
# count  50.000000  50.000000  50.000000
# mean    2.890678   2.895184  -3.141999
# std     0.856043   0.975277   0.981929
# min     0.869520   0.608983  -5.314050
# 25%     2.388591   2.203275  -3.778482
# 50%     2.878609   2.869157  -3.099467
# 75%     3.404175   3.470566  -2.493061
# max     5.135529   5.632271  -1.084452

# %%
plt.figure(figsize=(20,10))
plt.scatter(df4['nx'],df4['nb'],alpha=0.4)
plt.scatter(df4['nx'],df4['na'],alpha=0.4,color="yellow")
plt.scatter(df4['nb'],df4['na'],alpha=1.0,color="green")

plt.xlim(-1,8)
plt.ylim(-8,8)
# Out:
# (-8, 8)
